# %%
import pytrends
from pytrends.request import TrendReq
import pandas as pd
import time
import datetime
from datetime import datetime, date, time

# %%
#'Hafer','Weizen', 'Getreide','Raps', 'Soja'

# %%
#to get interest over time score, you'll need pytrend.interest_over_time() function.
#For more functions, check this: https://github.com/GeneralMills/pytrends
pytrend = TrendReq()
pytrend.build_payload(kw_list=['Hafer','Weizen', 'Getreide','Raps', 'Soja'], timeframe='today 12-m', geo = 'DE')


interest_over_time_df = pytrend.interest_over_time() 
print(interest_over_time_df.head())
# Out:
#             Hafer  Weizen  Getreide  Raps  Soja isPartial
# date
# 2019-03-31     33      63        38    27    44     False
# 2019-04-07     31      61        45    26    46     False
# 2019-04-14     30      66        39    24    45     False
# 2019-04-21     30      66        41    41    39     False
# 2019-04-28     28      67        43    38    42     False

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
dx = interest_over_time_df.plot.line(figsize = (9,6), title = "Interest Over Time")
dx.set_xlabel('Date')
dx.set_ylabel('Trends Index')
dx.tick_params(axis='both', which='major', labelsize=13)

# %%
#to get interest over time score, you'll need pytrend.interest_over_time() function.
#For more functions, check this: https://github.com/GeneralMills/pytrends
pytrend = TrendReq()
pytrend.build_payload(kw_list=['H5n1','ASP', 'BSE'], timeframe='today 12-m', geo = 'DE')


interest_over_time_df = pytrend.interest_over_time() 
print(interest_over_time_df.head())
# Out:
#             H5n1  ASP  BSE isPartial
# date
# 2019-03-31     2   69   16     False
# 2019-04-07     1   71   12     False
# 2019-04-14     1   68   12     False
# 2019-04-21     1   64   13     False
# 2019-04-28     1   73   14     False

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
dx = interest_over_time_df.plot.line(figsize = (9,6), title = "Interest Over Time")
dx.set_xlabel('Date')
dx.set_ylabel('Trends Index')
dx.tick_params(axis='both', which='major', labelsize=13)

# %%
#to get interest over time score, you'll need pytrend.interest_over_time() function.
#For more functions, check this: https://github.com/GeneralMills/pytrends
pytrend = TrendReq()
pytrend.build_payload(kw_list=['Erntebericht','Weizenpreis', 'Getreidepreise','Weizenhandel', 'Weizenprognosen'], timeframe='today 12-m', geo = 'DE')


interest_over_time_df = pytrend.interest_over_time() 
print(interest_over_time_df.head())
# Out:
#             Erntebericht  Weizenpreis  Getreidepreise  Weizenhandel  \
# date
# 2019-03-31             6           50               8             0
# 2019-04-07             6           47              13             0
# 2019-04-14             0           29               9             0
# 2019-04-21             6           38              12             0
# 2019-04-28             0           24               0             0
#
#             Weizenprognosen isPartial
# date
# 2019-03-31                0     False
# 2019-04-07                0     False
# 2019-04-14                0     False
# 2019-04-21                0     False
# 2019-04-28                0     False

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
dx = interest_over_time_df.plot.line(figsize = (9,6), title = "Interest Over Time")
dx.set_xlabel('Date')
dx.set_ylabel('Trends Index')
dx.tick_params(axis='both', which='major', labelsize=13)

# %%
#to get interest over time score, you'll need pytrend.interest_over_time() function.
#For more functions, check this: https://github.com/GeneralMills/pytrends
pytrend = TrendReq()
pytrend.build_payload(kw_list=['Tulpen','Rosen', 'Topfrosen','Garten'], timeframe='today 12-m', geo = 'DE')


interest_over_time_df = pytrend.interest_over_time() 
print(interest_over_time_df.head())
# Out:
#             Tulpen  Rosen  Topfrosen  Garten isPartial
# date
# 2019-03-31       4     23          0      71     False
# 2019-04-07       4     22          0      71     False
# 2019-04-14       4     22          0      82     False
# 2019-04-21       4     23          0      85     False
# 2019-04-28       3     23          0      67     False

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
dx = interest_over_time_df.plot.line(figsize = (9,6), title = "Interest Over Time")
dx.set_xlabel('Date')
dx.set_ylabel('Trends Index')
dx.tick_params(axis='both', which='major', labelsize=13)
